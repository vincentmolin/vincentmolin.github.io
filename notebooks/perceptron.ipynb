# %% [markdown]
# # A simple perceptron
# Date: 2021-02-15 21:51
# Author: Vincent
# <!--eofm-->
#
# Some year around the time when we started using computers, the 50s or so, someone came up with the
# idea of the *perceptron*: the brain-inspired machine that could learn! Even though the author
# had high hopes for this model, it sadly couldn't learn very much. It is however very easy to
# implement, so let's do it.

# %%
# Start writing code here...
